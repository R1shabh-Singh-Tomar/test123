# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
data = pd.read_csv('LP_2023_Append_Complete.csv', encoding = 'latin1', low_memory = False)

# %%
data
# Out:
#        processName flowsWriteoff  uniqueTdfCustId  ucicCode allocationMonth  \
# 0          LAZYPAY      Writeoff       6205145246       NaN           April
# 1          LAZYPAY      Writeoff       6300253866       NaN           April
# 2          LAZYPAY      Writeoff       6351477362       NaN           April
# 3          LAZYPAY      Writeoff       6363104150       NaN           April
# 4          LAZYPAY      Writeoff       6379100398       NaN           April
# ...            ...           ...              ...       ...             ...
# 663617     LAZYPAY      Writeoff       9999871540       NaN             May
# 663618     LAZYPAY      Writeoff       9999912555       NaN             May
# 663619     LAZYPAY      Writeoff       9999951970       NaN             May
# 663620     LAZYPAY      Writeoff       9999992101       NaN             May
# 663621     LAZYPAY      Writeoff       9999993061       NaN             May
#
# ...

# %%
sqlEngine = create_engine('mysql+pymysql://root:igdefault@localhost:3306/tdf', pool_recycle=3600)

print("DB is working....")
# Out:
# DB is working....

# %%
data.to_sql('LP_2023', sqlEngine, if_exists = 'append', index = False)

print("Data has been exported....")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
